# %% [markdown]
# <a href="https://colab.research.google.com/github/janzaw04/machinelearning/blob/main/WYK3_Zadanie_ZawadzkiJan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import random

# %%
env = gym.make("Taxi-v3").env
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.reset() # reset environment to a new, random state
env.render()

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# Action Space Discrete(6)
# State Space Discrete(500)

# %%
env.step(1)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %%
env.step(2)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)

# %%
env.step(3)
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)

# %%
env.P
env.P[199]
# Out:
# {0: [(1.0, 299, -1, False)],
#  1: [(1.0, 99, -1, False)],
#  2: [(1.0, 199, -1, False)],
#  3: [(1.0, 179, -1, False)],
#  4: [(1.0, 199, -10, False)],
#  5: [(1.0, 199, -10, False)]}

# %%
for t in range(199):
  action = env.action_space.sample()
  observation, reward, done, info = env.step(action)
  print(t, observation, reward, done)
# Out:
# 0 68 -1 False
# 1 88 -1 False
# 2 88 -1 False
# 3 68 -1 False
# 4 68 -10 False
# 5 48 -1 False
# 6 48 -10 False
# 7 48 -10 False
# 8 48 -10 False
# 9 48 -1 False
# 10 48 -1 False
# 11 48 -10 False
# 12 68 -1 False
# 13 168 -1 False
# 14 168 -10 False
# 15 268 -1 False
# 16 268 -10 False
# 17 268 -10 False
# 18 168 -1 False
# 19 168 -10 False
# 20 168 -10 False
# 21 268 -1 False
# 22 168 -1 False
# 23 268 -1 False
# 24 268 -10 False
# 25 288 -1 False
# 26 288 -10 False
# 27 288 -10 False
# 28 288 -10 False
# 29 268 -1 False
# 30 268 -10 False
# 31 248 -1 False
# 32 248 -10 False
# 33 248 -10 False
# 34 348 -1 False
# 35 248 -1 False
# 36 268 -1 False
# 37 248 -1 False
# 38 148 -1 False
# 39 148 -1 False
# 40 48 -1 False
# 41 48 -10 False
# 42 48 -10 False
# 43 48 -1 False
# 44 148 -1 False
# 45 148 -10 False
# 46 148 -10 False
# 47 248 -1 False
# 48 268 -1 False
# 49 268 -10 False
# 50 248 -1 False
# 51 248 -10 False
# 52 248 -10 False
# 53 268 -1 False
# 54 268 -10 False
# ...

# %%
for t in range(199):
  action = env.action_space.sample()
  observation, reward, done, info = env.step(action)
  env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# ...
